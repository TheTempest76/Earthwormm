# %%
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch
import torch.nn as nn
from torchvision import models
import torch.optim as optim

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
data = pd.read_csv("data_normalized.csv")

# Create a mapping for categories
unique_categories = data['Category'].unique()
category_mapping = {category: idx for idx, category in enumerate(unique_categories)}
category_mapping
# Out:
# {'Unripe': 0, 'overripe': 1, 'ripe': 2}

# %%
from sklearn.preprocessing import MinMaxScaler

# Load CSV
data = pd.read_csv('topg.csv')

# Normalize specific columns
columns_to_normalize = ['Freshness', 'Shape and Size', 'Texture', 'Color', 'Firmness', 
                        'Batch Consistency', 'Overall Quality']
scaler = MinMaxScaler()
data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])

# Save normalized data if needed
data.to_csv('data_normalized.csv', index=False)
print("Normalized CSV saved.")
# Out:
# Normalized CSV saved.

# %%
class ImageDataset(Dataset):
    def __init__(self, csv_file, image_dir, transform=None):
        self.data = pd.read_csv(csv_file)
        self.image_dir = image_dir
        self.transform = transform

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        image_path = os.path.join(self.image_dir, row['file_path'])
        image = Image.open(image_path).convert("RGB")
        category_idx = category_mapping[row['Category']]
        if self.transform:
            image = self.transform(image)

        labels = {
            'Category': torch.tensor(category_idx, dtype=torch.long),  # Long tensor for category            'Freshness': torch.tensor(row['Freshness'], dtype=torch.float),  # Float tensor for regression
            'Shape_and_Size': torch.tensor(row['Shape and Size'], dtype=torch.float),
            'Texture': torch.tensor(row['Texture'], dtype=torch.float),
            'Color': torch.tensor(row['Color'], dtype=torch.float),
            'Firmness': torch.tensor(row['Firmness'], dtype=torch.float),
            'Batch_Consistency': torch.tensor(row['Batch Consistency'], dtype=torch.float),
            'Damaged': torch.tensor(row['Damaged'], dtype=torch.float),  # Float tensor for binary classification
            'Overall_Quality': torch.tensor(row['Overall Quality'], dtype=torch.float),
        }

        return image, labels


    def __len__(self):
        return len(self.data)

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

transform
# Out:
# Compose(
#     Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=True)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )

# %%
# Load dataset  
image_dir = ''
csv_file = 'data_normalized.csv'
dataset = ImageDataset(csv_file=csv_file, image_dir=image_dir, transform=transform)

# Split into training and validation sets
from torch.utils.data import random_split

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=10, shuffle=False)

# %%
# Add error handling and logging
try:
    for images, labels in train_loader:
        images = images.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
        
        # Debugging: Print shapes
        print("Image shape:", images.shape)
        for key, value in labels.items():
            print(f"{key} shape: {value.shape}")
        
        # Rest of the training code...
except Exception as e:
    print(f"Error during training: {e}")
# Out:
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])
# Image shape: torch.Size([10, 3, 224, 224])
# Category shape: torch.Size([10])
# Shape_and_Size shape: torch.Size([10])
# Texture shape: torch.Size([10])
# Color shape: torch.Size([10])
# Firmness shape: torch.Size([10])
# Batch_Consistency shape: torch.Size([10])
# Damaged shape: torch.Size([10])
# Overall_Quality shape: torch.Size([10])

# %%
# Check pixel value statistics
for i in range(3):  # Check first 3 samples
    image, label = train_dataset[i]
    print(f"Image Mean: {image.mean():.4f}, Image Std: {image.std():.4f}, Label: {label}")
# Out:
# Image Mean: 0.5182, Image Std: 0.9516, Label: {'Category': tensor(2), 'Shape_and_Size': tensor(0.8000), 'Texture': tensor(1.), 'Color': tensor(0.8333), 'Firmness': tensor(0.8889), 'Batch_Consistency': tensor(0.8571), 'Damaged': tensor(0.), 'Overall_Quality': tensor(0.8780)}
# Image Mean: 2.2041, Image Std: 0.7867, Label: {'Category': tensor(0), 'Shape_and_Size': tensor(0.4000), 'Texture': tensor(0.7143), 'Color': tensor(0.6667), 'Firmness': tensor(0.6667), 'Batch_Consistency': tensor(0.7143), 'Damaged': tensor(0.), 'Overall_Quality': tensor(0.6098)}
# Image Mean: 2.1634, Image Std: 0.6671, Label: {'Category': tensor(0), 'Shape_and_Size': tensor(0.4000), 'Texture': tensor(0.7143), 'Color': tensor(0.6667), 'Firmness': tensor(0.7778), 'Batch_Consistency': tensor(0.5714), 'Damaged': tensor(0.), 'Overall_Quality': tensor(0.6098)}

# %%
# Model Definition
class MultiOutputResNet(nn.Module):
    def __init__(self, num_categories):
        super(MultiOutputResNet, self).__init__()
        self.base_model = models.resnet50(pretrained=True)
        num_features = self.base_model.fc.in_features
        
        # Replace the classification head with task-specific heads
        self.base_model.fc = nn.Identity()  # Remove original classification layer
        self.category_head = nn.Linear(num_features, num_categories)  # For Category
        self.shape_size_head = nn.Linear(num_features, 1)  # Regression
        self.texture_head = nn.Linear(num_features, 1)  # Regression
        self.color_head = nn.Linear(num_features, 1)  # Regression
        self.firmness_head = nn.Linear(num_features, 1)  # Regression
        self.batch_consistency_head = nn.Linear(num_features, 1)  # Regression
        self.damaged_head = nn.Linear(num_features, 1)  # Binary classification
        self.quality_head = nn.Linear(num_features, 1)  # Regression

    def forward(self, x):
        features = self.base_model(x)
        
        return {
            'Category': self.category_head(features),
            'Shape_and_Size': self.shape_size_head(features),
            'Texture': self.texture_head(features),
            'Color': self.color_head(features),
            'Firmness': self.firmness_head(features),
            'Batch_Consistency': self.batch_consistency_head(features),
            'Damaged': torch.sigmoid(self.damaged_head(features)),  # Sigmoid for binary output
            'Overall_Quality': self.quality_head(features)
        }

# %%
num_categories = len(dataset.data['Category'].unique())
model = MultiOutputResNet(num_categories)
model = model.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
num_categories
# Out:
# /home/afnaan/Desktop/labeling/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/afnaan/Desktop/labeling/.venv/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 3

# %%
criterion_category = nn.CrossEntropyLoss()
criterion_regression = nn.MSELoss()
criterion_binary = nn.BCEWithLogitsLoss()
# Optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)

# %%
# Training Loop
num_epochs = 10
accumulation_steps = 4  # Number of steps to accumulate gradients
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for i, (images, labels) in enumerate(val_loader):
        images = images.to(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
        
        # Forward pass
        outputs = model(images)
        
        # Debugging: Print shapes and values
        print(f"Epoch {epoch+1}, Batch {i+1}")
        print(f"outputs['Category'] shape: {outputs['Category'].shape}, labels['Category'] shape: {labels['Category'].shape}")
        print(f"outputs['Category'] values: {outputs['Category']}")
        print(f"labels['Category'] values: {labels['Category']}")
        
        # Compute Loss
        loss_category = criterion_category(outputs['Category'], labels['Category'].long().to(images.device))
        loss_shape_size = criterion_regression(outputs['Shape_and_Size'], labels['Shape_and_Size'].float().to(images.device))
        loss_texture = criterion_regression(outputs['Texture'], labels['Texture'].float().to(images.device))
        loss_color = criterion_regression(outputs['Color'], labels['Color'].float().to(images.device))
        loss_firmness = criterion_regression(outputs['Firmness'], labels['Firmness'].float().to(images.device))
        loss_batch_consistency = criterion_regression(outputs['Batch_Consistency'], labels['Batch_Consistency'].float().to(images.device))
        loss_damaged = criterion_binary(outputs['Damaged'], labels['Damaged'].float().unsqueeze(1).to(images.device))
        loss_quality = criterion_regression(
            outputs['Overall_Quality'], 
            labels['Overall_Quality'].float().view(-1, 1).to(images.device)
        )

        total_loss = (
            loss_category + loss_shape_size + loss_texture + 
            loss_color + loss_firmness + loss_batch_consistency + 
            loss_damaged + loss_quality
        )

        # Backward pass and optimization
        total_loss = total_loss / accumulation_steps
        total_loss.backward()
        
        if (i + 1) % accumulation_steps == 0:
            optimizer.step()
            optimizer.zero_grad()
        
        running_loss += total_loss.item()
        
        # Clear cache to avoid OOM
        torch.cuda.empty_cache()

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {running_loss / len(val_loader):.4f}")
# Out:
# Epoch 1, Batch 1
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.2372, -0.6451,  0.3219],
#         [-0.1595, -0.7402, -0.0879],
#         [ 0.0734, -0.3081,  0.1005],
#         [-0.4236, -0.6393, -0.0669],
#         [ 0.0250, -0.4056,  0.2265],
#         [ 0.1022, -0.4359, -0.3173],
#         [ 0.4041, -0.5590, -0.1423],
#         [-0.1318, -0.2892, -0.1394],
#         [ 0.3834, -0.3910, -0.0580],
#         [ 0.2472, -0.8049, -0.3480]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 1, 2, 1, 0, 2, 0, 1, 0, 0])
# /home/afnaan/Desktop/labeling/.venv/lib/python3.12/site-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([10])) that is different to the input size (torch.Size([10, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 1, Batch 2
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.0659, -0.2939,  0.0423],
#         [ 0.1435, -0.4644, -0.0700],
#         [ 0.2281, -0.6605, -0.0263],
#         [ 0.2630, -0.6581,  0.0441],
#         [ 0.0946, -0.3916, -0.1993],
#         [-0.2560, -0.4946, -0.0995],
#         [-0.1219, -0.5443, -0.0906],
#         [-0.0434, -0.5165, -0.0688],
#         [ 0.2612, -0.5274,  0.1661],
#         [ 0.0349, -0.5724, -0.2702]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 0, 2, 1, 0, 1, 1, 1])
# Epoch 1, Batch 3
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.1227, -0.4819,  0.1105],
#         [-0.0181, -0.9220, -0.3242],
#         [ 0.0677, -0.1843, -0.1131],
#         [ 0.1161, -0.4336,  0.2400],
#         [ 0.3638, -0.3128, -0.0838],
#         [ 0.2715, -0.4595,  0.0661],
#         [-0.4618, -0.5802, -0.0769],
#         [ 0.4691, -0.3303,  0.1732],
#         [-0.3014, -0.9506, -0.3416],
#         [ 0.3115, -0.5655,  0.0045]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 2, 0, 2, 0, 1, 0, 2, 0])
# Epoch 1, Batch 4
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.0597, -0.3046,  0.1625],
#         [-0.1631, -0.6251, -0.1869],
#         [ 0.1036, -0.4410, -0.2171],
#         [ 0.0660, -0.3217,  0.0057],
#         [ 0.2102, -0.7396, -0.4634],
#         [ 0.1624, -0.6432,  0.1428],
#         [ 0.0667, -0.4645,  0.0202],
#         [-0.0787, -0.5422, -0.3487],
#         [ 0.4051, -0.5940,  0.2653],
#         [-0.0458, -0.5446,  0.2042]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 0, 0, 0, 0, 2, 0, 2])
# Epoch 1, Batch 5
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.2983,  0.2379, -1.0803],
#         [ 0.6964,  0.0225, -1.0710],
#         [ 3.0581, -0.6549, -2.4673],
#         [ 1.1271,  0.4821, -2.1206],
#         [-0.6149,  0.1230,  0.2859],
#         [ 0.5949, -0.3498, -0.2392],
#         [-0.8015,  1.1989, -0.5205],
#         [-0.2404, -0.4606,  0.2150],
#         [ 2.9003, -1.4876, -1.6525],
#         [-0.8362,  0.1094,  0.2298]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 1, 0, 1, 0, 2, 1, 2, 0, 2])
# Epoch 1, Batch 6
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.7933,  0.4500,  0.1284],
#         [-0.7664,  0.2061, -0.2625],
#         [ 2.6276, -0.7715, -2.0885],
#         [-0.1301, -0.1598, -0.2290],
#         [ 1.5098, -0.2893, -1.5303],
#         [ 1.1698, -0.8735, -0.8530],
#         [ 3.3434, -0.1331, -2.9269],
#         [-0.3306, -0.4151,  0.1603],
#         [-1.1446,  0.9769,  0.0451],
#         [ 0.5121, -0.0222, -0.8197]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 0, 2, 0, 0, 0, 2, 1, 2])
# Epoch 1, Batch 7
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.9207, -0.1829, -0.8730],
#         [-1.1507,  0.5856,  0.4030],
#         [ 3.0632, -1.1430, -2.3836],
#         [ 1.2264,  0.0965, -1.9632],
#         [-0.6231,  0.1177,  0.2197],
#         [ 0.7997,  0.3633, -1.6483],
#         [-0.7079, -0.4179,  0.4785],
#         [-0.3401,  0.0579,  0.0825],
#         [ 2.9440, -0.8309, -2.0729],
#         [ 0.1819,  0.3034, -0.8190]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 0, 1, 2, 1, 2, 0, 0, 0])
# Epoch 1, Batch 8
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.2564, -0.2440,  0.2352],
#         [ 0.3194, -0.3693, -0.2262],
#         [ 2.5335, -0.7324, -2.5334],
#         [ 1.0486,  0.5439, -2.1747],
#         [ 0.8127, -0.3347, -0.4933],
#         [ 0.7729,  0.2503, -1.3527],
#         [-1.1628,  0.1945,  0.5401],
#         [ 1.9728, -0.5646, -1.7868],
#         [ 0.4371, -0.3578, -0.3153],
#         [-0.5828,  0.6062, -0.1611]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 0, 1, 2, 1, 2, 0, 2, 0])
# Epoch 1, Batch 9
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.3169, -0.1858,  0.4357],
#         [-1.0941, -0.0225,  0.9228],
#         [ 0.4324, -0.0437, -0.6804],
#         [-0.8301,  0.1249,  0.2629],
#         [ 2.6147, -0.2054, -2.4705],
#         [ 0.9826, -0.0382, -1.2808],
#         [-0.5158,  0.2492,  0.2059],
#         [ 1.9742, -0.5371, -1.9291],
#         [ 0.8071,  0.0798, -1.2500],
#         [-1.3149,  1.2009, -0.2373]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 2, 2, 0, 0, 1, 0, 0, 1])
# Epoch 1, Batch 10
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.1558, -0.0184,  0.9236],
#         [ 2.7754, -0.6855, -2.1139],
#         [ 1.0968, -0.2058, -1.1177],
#         [-0.9356,  0.7334,  0.3386],
#         [-1.0213, -0.2299,  0.9145],
#         [ 2.5323, -0.5572, -2.3770],
#         [-1.1224,  0.8942, -0.2469],
#         [ 1.3432, -0.0262, -2.1512],
#         [-0.1862, -0.2170,  0.4174],
#         [-0.7454,  1.0290, -0.4221]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 1, 1, 2, 0, 1, 0, 2, 1])
# Epoch 1, Batch 11
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-5.0125e-01, -3.7103e-02,  3.3476e-01],
#         [ 7.2626e-01, -5.4977e-04, -7.8505e-01],
#         [-1.3995e+00,  4.8333e-02,  9.2804e-01],
#         [-1.0439e-01,  7.0937e-01, -8.2694e-01],
#         [-4.6126e-01, -4.4864e-01,  4.4565e-01],
#         [ 2.6990e+00, -4.4467e-01, -2.3576e+00],
#         [ 2.2106e+00, -6.8416e-01, -1.6450e+00],
#         [-9.9397e-01,  6.8218e-01,  3.1498e-01],
#         [ 1.1789e+00, -4.0746e-01, -1.4428e+00],
#         [-6.0568e-01,  1.2872e+00, -8.5608e-01]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 0, 1, 2, 0, 0, 1, 0, 1])
# Epoch 1, Batch 12
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 2.0360, -0.0950, -2.5403],
#         [ 1.1262,  0.0035, -1.3579],
#         [ 1.3566, -0.2987, -1.3636],
#         [-0.7003,  0.8935, -0.3486],
#         [-1.6034,  0.1656,  0.8585],
#         [ 0.4269, -0.1289, -0.0775],
#         [-0.5297, -0.3077,  0.3874],
#         [-0.9229,  1.0413,  0.0168],
#         [ 0.7370, -0.1655, -0.9027],
#         [ 0.7568, -0.2920, -0.4441]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 0, 0, 1, 2, 2, 2, 1, 0, 2])
# Epoch 1, Batch 13
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.3638, -0.3169, -0.5272],
#         [-0.2358, -0.5672,  0.4818],
#         [-0.1487,  0.2527, -0.6418],
#         [-1.0347,  1.8127, -1.0933],
#         [ 0.1657,  0.2407, -0.7033],
#         [ 0.0190, -0.8349,  0.4996],
#         [ 0.1210, -0.4975,  0.1881],
#         [ 2.1827, -0.0431, -2.3752],
#         [ 0.3612, -0.1149, -0.6869],
#         [-1.3000, -0.0201,  0.8599]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 2, 0, 1, 0, 0, 1, 2, 1, 2])
# Epoch 1, Batch 14
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-7.4590e-01,  2.2097e-01,  2.0278e-01],
#         [ 4.6615e-01, -1.2323e-01, -4.9247e-01],
#         [-1.9081e-01,  1.0846e+00, -1.0335e+00],
#         [ 2.2481e+00, -5.2195e-01, -2.3396e+00],
#         [ 4.4471e-01, -6.0844e-01, -1.7454e-01],
#         [-1.2906e+00,  1.1991e-03,  7.6676e-01],
#         [-1.1291e+00,  5.5534e-01,  3.0715e-01],
#         [-7.5281e-01, -1.6419e-01,  6.2334e-01],
#         [ 1.2231e+00,  2.1776e-01, -1.8578e+00],
#         [-2.3710e-01, -5.9148e-01,  3.4066e-01]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 1, 2, 1, 2, 2, 0, 0, 2])
# Epoch 1, Batch 15
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.8190,  0.5035, -0.0563],
#         [ 1.1726, -0.1416, -1.8345],
#         [-0.2802,  0.2765, -0.4742],
#         [ 1.2988, -0.2819, -1.5853],
#         [ 0.7353, -0.6847, -0.2216],
#         [ 0.1288, -0.7201,  0.1760],
#         [-1.0107,  1.4814, -0.6994],
#         [ 0.9802,  0.0795, -1.1199],
#         [-1.4209, -0.1767,  1.0868],
#         [-0.5756, -0.4377,  0.6887]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 2, 2, 2, 1, 0, 0, 2])
# Epoch 1, Batch 16
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.8106, -0.3496,  0.7304],
#         [-1.0880,  0.2389,  0.6155],
#         [ 0.2896, -0.5484,  0.0490],
#         [ 2.1539, -0.5172, -2.2664],
#         [ 1.5711,  0.0774, -1.7439],
#         [-0.0249, -0.4521,  0.0393],
#         [ 0.5969, -0.5055, -0.6487],
#         [-1.1321,  0.2524,  0.6402],
#         [-0.8708,  1.9067, -1.4431],
#         [-0.5437, -0.2466,  0.4938]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 2, 2, 2, 0, 2, 2, 2, 1, 0])
# Epoch 1, Batch 17
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.1048,  2.3222, -2.0586],
#         [-0.9118, -0.4154,  0.7831],
#         [-0.6607, -0.4638,  0.8710],
#         [-0.3200, -0.4738,  0.4586],
#         [ 1.4217, -0.8676, -0.8243],
#         [-0.6876, -0.4937,  0.7350],
#         [-0.4373, -0.7149,  0.7866],
#         [-0.1003, -0.7905, -0.1857],
#         [-0.6876, -0.4937,  0.7350],
#         [ 0.3695, -0.9228, -0.6334]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 2, 0, 0, 2, 0, 1, 2, 0])
# Epoch 1, Batch 18
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.0790,  1.0950, -0.9395],
#         [ 0.4397, -0.6817, -0.0486],
#         [-1.2619, -0.0426,  1.0436],
#         [-0.0799, -0.5670,  0.2793],
#         [ 0.3054, -0.9027, -0.4298],
#         [-1.0927,  0.2033,  0.4159],
#         [ 0.5375, -1.1026, -0.7322],
#         [ 0.4550, -0.7231,  0.0308],
#         [-0.3986, -0.2987,  0.2213],
#         [-1.1174, -0.4693,  0.8272]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 2, 0, 0, 2, 0, 0, 1, 2])
# Epoch 1, Batch 19
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 1.0628e-02, -5.0651e-01,  1.5101e-03],
#         [-8.6068e-01,  1.7254e+00, -1.6207e+00],
#         [-1.4797e+00,  3.6861e-01,  4.4730e-01],
#         [-5.4103e-01, -4.9743e-01,  8.3031e-02],
#         [-5.4481e-02, -6.0089e-01, -6.1680e-03],
#         [-9.2562e-01, -6.4971e-01,  1.1939e+00],
#         [-9.0439e-01, -7.0231e-01,  1.0532e+00],
#         [ 7.8555e-01, -8.9071e-01, -1.2653e-01],
#         [ 1.0289e-01, -9.1045e-01, -2.0308e-01],
#         [ 7.1893e-01, -7.4824e-01, -2.1319e-01]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 1, 2, 0, 0, 0, 2, 0, 0, 0])
# Epoch 1, Batch 20
# outputs['Category'] shape: torch.Size([8, 3]), labels['Category'] shape: torch.Size([8])
# outputs['Category'] values: tensor([[-0.4731, -1.1185,  0.8179],
#         [ 0.1426, -0.7539, -0.8742],
#         [-2.5654,  1.7380,  0.3409],
#         [ 0.1503, -0.1744, -0.4685],
#         [ 1.1910, -0.3998, -1.0835],
#         [-0.4715, -0.4162,  0.5358],
#         [-0.4832, -0.8201,  0.6690],
#         [-0.4112, -0.6492,  0.5459]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 2, 0, 0, 0, 2, 0])
# Epoch 1/10, Loss: 1.1515
# /home/afnaan/Desktop/labeling/.venv/lib/python3.12/site-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch 2, Batch 1
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.2497, -0.7356,  0.5572],
#         [-0.6178, -0.8622,  0.9600],
#         [-0.8781, -0.9088,  1.1014],
#         [-1.9157,  0.9282,  0.3676],
#         [ 0.4040, -0.8659,  0.0664],
#         [-0.9814, -1.1690,  1.2015],
#         [ 0.8706, -0.8010, -0.5480],
#         [-0.1687, -1.0621,  0.2812],
#         [ 0.4956, -0.6906, -0.2337],
#         [ 0.3640, -1.4749, -0.7945]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 1, 2, 1, 0, 2, 0, 1, 0, 0])
# Epoch 2, Batch 2
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.8745, -0.6362,  1.1143],
#         [ 0.9360, -1.6787, -0.8676],
#         [-0.4588, -0.6679,  0.4759],
#         [ 0.5269, -1.3226,  0.3226],
#         [-0.6537, -1.0278,  1.2179],
#         [-1.2548,  0.1830,  0.3570],
#         [-0.6509, -0.9237,  1.0920],
#         [-0.2751,  0.6322, -1.1937],
#         [ 0.1076, -0.8491, -0.0045],
#         [-0.1032, -1.2614,  0.4441]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 0, 2, 1, 0, 1, 1, 1])
# Epoch 2, Batch 3
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.1400, -1.0006, -0.0015],
#         [-0.2326, -1.3601,  0.6268],
#         [-0.7792, -1.0048,  0.8857],
#         [ 0.7362, -1.0240, -0.1208],
#         [-0.8836, -1.0476,  1.0294],
#         [-0.3010, -0.9831,  0.8275],
#         [-1.4636,  0.3759,  0.4933],
#         [ 0.3548, -0.5522, -0.3822],
#         [-0.3768, -1.2507,  0.5987],
#         [ 0.2414,  0.1290, -1.0120]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 2, 0, 2, 0, 1, 0, 2, 0])
# Epoch 2, Batch 4
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.7078, -0.4117,  0.8653],
#         [-0.5745, -0.7629,  0.9583],
#         [ 0.0440, -1.3024, -0.3634],
#         [-0.5673, -0.9528,  0.8347],
#         [-0.4859, -0.9736,  0.4242],
#         [ 0.8191, -0.3707, -0.9811],
#         [-0.0836, -1.0193, -0.1707],
#         [-0.6386, -0.8757,  1.1426],
#         [ 0.1742,  0.1593, -0.9523],
#         [-0.6812, -0.6521,  0.9499]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 0, 0, 0, 0, 2, 0, 2])
# Epoch 2, Batch 5
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.1338, -0.6533,  0.4204],
#         [ 0.3898, -0.8862, -0.3820],
#         [-0.3396, -0.9564,  0.8441],
#         [-1.5647,  0.6280,  0.3397],
#         [-0.3832, -0.9295,  0.8978],
#         [-0.5974, -1.0582,  1.1205],
#         [-0.0742, -0.6430,  0.0898],
#         [ 0.6918, -1.6934, -0.4827],
#         [ 1.7123, -2.0579, -1.4037],
#         [-0.6208, -1.3809,  1.1290]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 1, 0, 1, 0, 2, 1, 2, 0, 2])
# Epoch 2, Batch 6
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.8161, -0.7868,  1.0132],
#         [-0.7267, -1.1217,  1.3156],
#         [ 1.8255, -0.8487, -2.4917],
#         [ 0.0804, -1.6850,  0.9845],
#         [ 1.4558, -1.2487, -1.0739],
#         [ 0.1109, -1.5141, -0.4000],
#         [-0.6407, -0.2951,  0.3906],
#         [-0.8730, -1.2560,  1.2657],
#         [-0.4495, -0.4990,  0.4881],
#         [-1.1303, -1.2140,  1.3725]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 0, 2, 0, 0, 0, 2, 1, 2])
# Epoch 2, Batch 7
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.8690, -0.2986, -0.2152],
#         [-0.6288, -1.0728,  1.2357],
#         [ 1.1834, -1.9030, -0.1373],
#         [-0.4388, -0.8982, -0.0404],
#         [-0.5059, -0.9140,  1.0279],
#         [-0.4063, -0.8568,  0.0231],
#         [-0.5471, -1.3240,  1.0106],
#         [-0.0064, -1.0124,  0.4659],
#         [ 0.4268, -0.7647, -0.3636],
#         [ 0.7686, -1.0078, -0.3665]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 0, 1, 2, 1, 2, 0, 0, 0])
# Epoch 2, Batch 8
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.7497, -1.2122,  1.2852],
#         [-0.4583, -1.2170,  0.7570],
#         [ 1.6603, -1.5193, -0.8996],
#         [-1.4651,  0.4693,  0.1571],
#         [-0.6783, -1.1335,  0.9655],
#         [-0.3978, -0.6224, -0.2393],
#         [-0.2271, -1.5952,  0.5003],
#         [ 0.7022, -1.4512,  0.2759],
#         [-0.3805, -1.0999,  0.2402],
#         [ 0.7970, -0.9015, -0.4973]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 0, 1, 2, 1, 2, 0, 2, 0])
# Epoch 2, Batch 9
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.8880, -1.3519,  1.5285],
#         [-0.5168, -0.9746,  0.9655],
#         [-1.2539, -0.6082,  1.1903],
#         [ 1.0809, -1.3011, -0.7529],
#         [-0.3361, -1.3312,  0.5900],
#         [ 1.2619, -1.6680, -0.2466],
#         [ 0.2341, -0.6930, -0.1539],
#         [ 2.4145, -1.7547, -1.5659],
#         [-0.6573, -1.1454,  0.5861],
#         [-1.3960,  0.4603, -0.3160]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 2, 2, 0, 0, 1, 0, 0, 1])
# Epoch 2, Batch 10
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.0415, -1.1105,  0.4580],
#         [ 0.1384, -1.1975,  0.5909],
#         [-0.5023, -0.8030,  0.5232],
#         [-0.3839, -0.7788,  0.1225],
#         [-0.3330, -1.1645,  1.0252],
#         [ 3.1675, -2.7175, -1.4081],
#         [-1.1516,  0.3103, -0.3644],
#         [-0.2514, -1.5660,  0.9863],
#         [-0.5809, -1.2419,  1.1981],
#         [-0.3009,  0.0590, -1.2598]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 1, 1, 2, 0, 1, 0, 2, 1])
# Epoch 2, Batch 11
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.4919, -1.0801,  1.0698],
#         [ 0.1772, -1.2249,  0.6159],
#         [ 0.4063, -0.6489, -0.5378],
#         [-0.6340,  0.1477, -1.0133],
#         [-0.9058, -1.3689,  1.4736],
#         [-0.3673, -1.4556,  0.7878],
#         [ 2.3353, -2.4913, -0.6137],
#         [-0.9700, -0.7114,  0.5482],
#         [ 1.0467, -1.6420, -0.0478],
#         [-0.3929, -0.1212, -0.4464]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 0, 1, 2, 0, 0, 1, 0, 1])
# Epoch 2, Batch 12
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 2.1296, -2.0261, -1.2038],
#         [ 0.6014, -1.1516, -0.3460],
#         [ 1.2120, -1.6177, -0.5227],
#         [-1.2069,  0.1596, -0.1649],
#         [-0.5481, -0.8932,  0.6104],
#         [-0.9101, -1.4869,  1.2382],
#         [-0.4021, -1.4072,  1.1659],
#         [-1.1971,  0.1797, -0.1559],
#         [ 1.1254, -1.8562,  0.0485],
#         [-0.6415, -1.1144,  0.9615]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 0, 0, 1, 2, 2, 2, 1, 0, 2])
# Epoch 2, Batch 13
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.3312, -1.0565,  0.5090],
#         [-0.3983, -0.8473,  0.5650],
#         [-0.0769, -1.3736,  0.7132],
#         [ 0.1625,  0.7798, -2.4974],
#         [ 0.0817, -1.0717,  0.1594],
#         [ 0.2402, -0.7623, -0.1127],
#         [ 0.0141, -0.3599, -0.1991],
#         [-0.3196, -1.1134,  0.9938],
#         [-0.0361, -0.5787,  0.2560],
#         [ 1.5216, -2.4500, -0.3205]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 2, 0, 1, 0, 0, 1, 2, 1, 2])
# Epoch 2, Batch 14
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.4644, -0.9051,  0.5748],
#         [ 0.0319, -1.0264,  0.5905],
#         [-1.7852,  1.4849, -0.5325],
#         [-0.2319, -0.8072,  0.6918],
#         [ 0.0835, -0.4789, -0.1465],
#         [-0.4847, -0.9538,  0.6377],
#         [-0.5131, -1.0079,  0.7362],
#         [ 4.0834, -2.6342, -2.8947],
#         [ 0.1094, -0.3870, -0.3890],
#         [-0.6640, -1.0271,  1.0886]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 1, 2, 1, 2, 2, 0, 0, 2])
# Epoch 2, Batch 15
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.0364,  0.3850, -0.1503],
#         [-0.0461, -0.7519,  0.1538],
#         [ 0.0062, -1.2553,  0.5021],
#         [-0.1696, -0.8167,  0.6476],
#         [-0.3643, -0.6163,  0.3074],
#         [-0.3655, -0.5910,  0.3713],
#         [-1.5220,  0.3296,  0.3672],
#         [ 0.3070, -0.6471, -0.2179],
#         [ 3.7316, -2.2377, -2.8198],
#         [-0.4883, -1.3647,  1.2564]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 2, 2, 2, 1, 0, 0, 2])
# Epoch 2, Batch 16
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 2.6147, -2.3025, -1.4611],
#         [-0.5893, -1.0957,  0.9843],
#         [-0.7402, -1.2368,  1.2341],
#         [-0.5208, -0.4884,  0.3869],
#         [ 0.0802, -0.5939, -0.0921],
#         [-0.4661, -0.7083,  0.6205],
#         [-0.0937, -1.0309,  0.6954],
#         [-0.5451, -1.1237,  0.7935],
#         [-2.0057,  2.1355, -1.1222],
#         [ 2.7650, -2.2102, -1.7016]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 2, 2, 2, 0, 2, 2, 2, 1, 0])
# Epoch 2, Batch 17
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.5697,  2.0652, -1.4152],
#         [-0.5314, -0.9843,  0.9276],
#         [ 0.0859, -0.1336, -0.5038],
#         [ 0.3239, -1.1230,  0.2878],
#         [ 3.9292, -3.1818, -2.0987],
#         [-0.5155, -0.7329,  0.4640],
#         [-0.2251, -0.8397,  0.5367],
#         [-0.1696, -0.2568, -0.3374],
#         [-0.5155, -0.7329,  0.4640],
#         [-0.0125, -1.4735,  0.6660]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 2, 0, 0, 2, 0, 1, 2, 0])
# Epoch 2, Batch 18
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.7700, -0.5435,  0.6045],
#         [ 2.3653, -1.2358, -2.3385],
#         [-0.6774, -0.7927,  0.8023],
#         [ 0.4805, -1.0490,  0.0743],
#         [-0.1322, -0.6373,  0.0483],
#         [-0.9910, -0.3914,  0.5824],
#         [-0.3970, -0.7036,  0.3579],
#         [ 2.0130, -1.7084, -1.2378],
#         [-0.2329,  0.5833, -0.9705],
#         [-0.9715, -0.9789,  1.2710]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 2, 0, 0, 2, 0, 0, 1, 2])
# Epoch 2, Batch 19
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.0541, -0.1061, -0.7251],
#         [-1.4337,  1.7506, -1.3665],
#         [-0.8173, -1.0723,  1.0726],
#         [-0.4101, -0.6996,  0.2904],
#         [ 0.0114, -0.3820, -0.3365],
#         [-0.3231, -0.3143,  0.2525],
#         [-0.6125, -1.1952,  1.2562],
#         [ 2.8073, -2.6240, -1.3414],
#         [-0.1257, -1.1639,  0.6186],
#         [ 1.9211, -2.0893, -0.6658]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 1, 2, 0, 0, 0, 2, 0, 0, 0])
# Epoch 2, Batch 20
# outputs['Category'] shape: torch.Size([8, 3]), labels['Category'] shape: torch.Size([8])
# outputs['Category'] values: tensor([[-0.7291, -1.0991,  1.2370],
#         [ 0.0052, -1.2138,  0.4482],
#         [-0.7697, -0.9521,  0.9114],
#         [-0.1056,  0.2510, -0.9936],
#         [ 3.1239, -2.1970, -2.1130],
#         [-0.0503,  0.0089, -0.6199],
#         [-0.7341, -0.7319,  0.9267],
#         [-0.1792, -0.1079, -0.4806]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 2, 0, 0, 0, 2, 0])
# Epoch 2/10, Loss: 0.5341
# Epoch 3, Batch 1
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 1.0524, -1.8104,  0.0350],
#         [ 0.3924,  0.2765, -1.6498],
#         [-0.8828, -0.8215,  0.8459],
#         [-1.5524,  2.2820, -1.7304],
#         [ 0.8956, -1.6355,  0.1297],
#         [-0.9216, -1.4776,  1.6088],
#         [ 0.5336, -1.4458, -0.0213],
#         [-0.1294, -0.0324, -0.5801],
#         [ 2.8267, -2.8347, -0.9448],
#         [ 0.8600, -1.4417, -0.3475]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 1, 2, 1, 0, 2, 0, 1, 0, 0])
# Epoch 3, Batch 2
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.1492,  0.1145, -0.9213],
#         [ 0.9109, -1.6327, -0.1832],
#         [ 0.6859, -0.7592, -0.6285],
#         [ 2.3952, -2.8124, -0.4499],
#         [-0.7951, -1.2118,  1.3366],
#         [-0.0056, -0.0944, -1.1704],
#         [-0.2287, -1.2268,  0.8820],
#         [-0.3588,  0.0832, -0.8922],
#         [ 0.4825, -0.2299, -0.9255],
#         [-0.4864, -0.5089,  0.4256]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 0, 2, 1, 0, 1, 1, 1])
# Epoch 3, Batch 3
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.1793,  0.4493, -1.5214],
#         [-1.0099, -1.1236,  1.2657],
#         [-0.6968, -1.0540,  0.9375],
#         [ 1.0769, -1.8054, -0.0086],
#         [-0.5008, -0.8278,  0.5848],
#         [ 1.6864, -2.1012, -0.5550],
#         [-1.1050,  2.4860, -2.4835],
#         [ 2.1457, -2.2810, -0.6098],
#         [ 0.0932, -0.8811, -0.1872],
#         [ 1.3419, -1.8233, -0.0331]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 2, 0, 2, 0, 1, 0, 2, 0])
# Epoch 3, Batch 4
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.1176,  0.9935, -1.6439],
#         [-0.0107, -0.5964,  0.0670],
#         [ 0.3444, -1.1126, -0.0306],
#         [-0.2091, -0.6612,  0.1463],
#         [-0.1871, -0.6152,  0.1027],
#         [ 1.7642, -2.1260, -0.5448],
#         [-0.1197, -0.8217,  0.1488],
#         [-0.9842, -0.2717,  0.5808],
#         [ 1.9295, -1.6634, -1.5887],
#         [-0.0359, -0.6731,  0.3781]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 0, 0, 0, 0, 2, 0, 2])
# Epoch 3, Batch 5
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.7848, -0.8924, -0.3264],
#         [ 0.0665,  0.0944, -0.8952],
#         [ 2.9736, -2.9303, -0.8885],
#         [-0.7716,  2.4452, -2.9051],
#         [ 0.5290, -0.3260, -0.8088],
#         [-1.0875, -1.4365,  1.5521],
#         [-0.0270,  0.3184, -0.8060],
#         [ 0.1826, -1.2725,  0.5515],
#         [ 1.9866, -2.0143, -0.9743],
#         [-0.4253, -1.3661,  1.0479]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 1, 0, 1, 0, 2, 1, 2, 0, 2])
# Epoch 3, Batch 6
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.2076,  0.1533, -0.4723],
#         [-0.4756, -1.0515,  0.9969],
#         [ 0.5813, -0.7744, -0.2973],
#         [-0.3356, -1.3958,  1.1243],
#         [ 1.3541, -0.8929, -1.1479],
#         [ 1.1017, -0.9097, -0.9605],
#         [ 3.0517, -2.0665, -2.2637],
#         [-0.1661, -1.3227,  0.8960],
#         [-0.4298,  1.8450, -2.1063],
#         [-1.1627, -0.1908,  0.5486]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 0, 2, 0, 0, 0, 2, 1, 2])
# Epoch 3, Batch 7
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.8761,  0.2784, -0.1000],
#         [-0.2070, -0.5954,  0.1909],
#         [ 1.3455, -2.2213, -0.0150],
#         [-0.5415,  1.2799, -1.7058],
#         [ 0.3424, -1.5667,  0.6973],
#         [-0.1636,  1.0853, -1.8771],
#         [-0.0744, -1.5715,  1.0708],
#         [ 0.3165,  0.1769, -1.4019],
#         [ 2.0865, -3.0980, -0.0124],
#         [ 2.2608, -1.6460, -1.4488]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 0, 1, 2, 1, 2, 0, 0, 0])
# Epoch 3, Batch 8
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.3935, -1.0890,  0.7658],
#         [-0.3382, -0.8684,  0.4109],
#         [ 1.4315, -1.6789, -0.1943],
#         [-0.9104,  2.8633, -3.0700],
#         [-0.5690, -0.9353,  0.8269],
#         [ 0.6907, -0.5776, -0.8156],
#         [-0.5033, -1.0390,  0.7590],
#         [ 3.4753, -3.0766, -1.3528],
#         [-0.3143, -0.7758,  0.3697],
#         [ 2.0443, -0.8547, -2.1125]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 0, 1, 2, 1, 2, 0, 2, 0])
# Epoch 3, Batch 9
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.5812, -1.4817,  1.3928],
#         [-0.5614, -1.1041,  1.0717],
#         [-0.9943,  0.9914, -0.5327],
#         [ 0.2057, -1.0949,  0.4895],
#         [ 1.9380, -1.5016, -1.6394],
#         [ 2.3771, -2.4951, -0.9246],
#         [-0.0351,  1.8778, -2.6667],
#         [ 2.5479, -2.1708, -1.1399],
#         [ 1.0264, -0.5870, -1.3974],
#         [-1.4110,  0.8030,  0.1416]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 2, 2, 0, 0, 1, 0, 0, 1])
# Epoch 3, Batch 10
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.6074e-03, -1.4237e+00,  8.7686e-01],
#         [ 1.2681e+00, -5.1980e-01, -1.6109e+00],
#         [ 1.4531e-02,  8.7492e-01, -1.5681e+00],
#         [-3.2881e-01, -1.2652e+00,  9.4541e-01],
#         [-2.5537e-01, -1.5800e+00,  1.2287e+00],
#         [ 3.4026e+00, -2.9715e+00, -1.4628e+00],
#         [-1.6036e+00,  2.0338e+00, -1.1292e+00],
#         [ 3.2724e+00, -2.2908e+00, -2.1841e+00],
#         [-2.1418e-01, -1.4150e+00,  1.0746e+00],
#         [-9.4141e-01,  1.7137e+00, -1.5342e+00]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 1, 1, 2, 0, 1, 0, 2, 1])
# Epoch 3, Batch 11
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.1174, -0.8208,  0.1154],
#         [ 0.5691, -1.5894,  0.5485],
#         [-0.1747,  1.4363, -1.9445],
#         [-0.5556, -0.2531,  0.3010],
#         [-0.0086, -1.4511,  0.6560],
#         [ 2.6854, -1.6094, -2.5006],
#         [ 2.3836, -2.6288, -0.6890],
#         [-1.2188,  0.4674,  0.1936],
#         [ 2.1938, -2.2565, -0.8972],
#         [-1.3486,  1.8354, -1.1119]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 0, 1, 2, 0, 0, 1, 0, 1])
# Epoch 3, Batch 12
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 1.6949, -1.9980, -0.5106],
#         [ 1.9182, -1.8344, -0.9222],
#         [ 2.2448, -2.2591, -0.8383],
#         [-1.3413,  1.7467, -0.9545],
#         [ 0.2734,  0.4444, -1.6298],
#         [ 0.3124, -1.0547,  0.0169],
#         [-0.0508, -1.6584,  1.0098],
#         [-1.3645,  2.2416, -1.6902],
#         [ 1.1691, -2.1762,  0.1180],
#         [ 0.1039, -0.7030, -0.1174]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 0, 0, 1, 2, 2, 2, 1, 0, 2])
# Epoch 3, Batch 13
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 1.4352, -1.2402, -1.0053],
#         [-0.4079, -1.0447,  0.8181],
#         [ 3.1036, -2.0046, -2.2978],
#         [-2.0947,  4.6750, -3.7025],
#         [ 3.3056, -2.3721, -2.0439],
#         [ 0.1531, -0.9652,  0.3741],
#         [ 0.1864, -0.0980, -0.5230],
#         [-0.0128, -1.3824,  0.8463],
#         [ 0.3554, -0.1379, -0.4701],
#         [-0.7746, -1.7465,  1.6380]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 2, 0, 1, 0, 0, 1, 2, 1, 2])
# Epoch 3, Batch 14
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.0914, -1.9901,  1.1282],
#         [ 0.9823, -1.3850, -0.3086],
#         [-2.1739,  4.6551, -3.1630],
#         [-0.5054, -1.1116,  1.0583],
#         [ 0.3696,  0.5648, -1.5394],
#         [-0.2624, -1.0515,  0.5552],
#         [-0.3357, -0.4083, -0.0373],
#         [ 4.6625, -2.8316, -2.8484],
#         [ 1.6422, -1.1024, -1.1114],
#         [ 0.1815, -1.5242,  0.5573]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 1, 2, 1, 2, 2, 0, 0, 2])
# Epoch 3, Batch 15
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.3183,  1.9453, -1.2994],
#         [ 0.9360, -0.1960, -1.4670],
#         [ 5.2069, -2.8579, -4.0700],
#         [-0.3632, -1.1085,  0.9765],
#         [ 0.0501, -1.3538,  0.8138],
#         [-0.2029, -1.1285,  0.7546],
#         [-1.3170,  2.8277, -2.5294],
#         [ 1.6065, -0.7848, -1.4305],
#         [ 1.2683, -1.8612,  0.0407],
#         [-0.4933, -2.0756,  1.7405]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 2, 2, 2, 1, 0, 0, 2])
# Epoch 3, Batch 16
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 3.6521, -2.6243, -2.0032],
#         [-0.2206, -1.4017,  0.8326],
#         [ 0.2626, -1.2437,  0.1993],
#         [-0.2286,  0.0647, -0.3841],
#         [ 1.4186, -0.8055, -1.2727],
#         [-0.3794, -1.0680,  0.8309],
#         [ 0.9929, -0.7646, -1.0412],
#         [-0.6967, -0.9498,  0.8075],
#         [-2.6243,  4.7072, -2.6829],
#         [ 2.7251, -2.1545, -1.3118]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 2, 2, 2, 0, 2, 2, 2, 1, 0])
# Epoch 3, Batch 17
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-2.6142,  4.6238, -2.5614],
#         [-0.2713, -1.4060,  1.0911],
#         [-0.0231, -0.1419, -0.2174],
#         [ 0.7365, -1.3330, -0.0645],
#         [ 4.2141, -2.6567, -2.6577],
#         [-0.4761, -1.4231,  1.2433],
#         [ 0.3455, -0.6074, -0.1977],
#         [-0.1009,  0.4681, -0.9631],
#         [-0.4761, -1.4231,  1.2433],
#         [ 2.8984, -2.0814, -2.2491]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 2, 0, 0, 2, 0, 1, 2, 0])
# Epoch 3, Batch 18
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.7341,  1.1809, -0.0745],
#         [ 3.4916, -1.9389, -2.5083],
#         [-0.9622, -0.3073,  0.6142],
#         [ 1.7301, -1.4488, -1.0541],
#         [ 0.8133, -1.0157, -0.6365],
#         [-2.6850,  2.5483, -0.6408],
#         [ 1.7569, -1.5173, -1.3598],
#         [ 2.4185, -2.0048, -1.3634],
#         [-0.4238, -0.1604,  0.1708],
#         [-0.0251, -1.3056,  0.7885]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 2, 0, 0, 2, 0, 0, 1, 2])
# Epoch 3, Batch 19
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.4915, -0.8344, -0.1635],
#         [-2.5181,  4.2276, -2.3785],
#         [-1.4170, -0.8359,  1.4020],
#         [ 0.4160, -0.1327, -1.1835],
#         [ 0.9268, -0.9231, -0.6444],
#         [-0.5570, -0.4633,  0.6258],
#         [-0.4451, -1.4439,  1.2329],
#         [ 3.2065, -2.2369, -1.8764],
#         [ 1.6322, -1.5005, -1.0761],
#         [ 2.7557, -1.9234, -1.6042]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 1, 2, 0, 0, 0, 2, 0, 0, 0])
# Epoch 3, Batch 20
# outputs['Category'] shape: torch.Size([8, 3]), labels['Category'] shape: torch.Size([8])
# outputs['Category'] values: tensor([[-0.6371, -1.7460,  1.6182],
#         [ 3.6972, -1.6195, -3.4934],
#         [-2.1627,  1.2134,  0.2039],
#         [ 1.2192, -0.5544, -1.3300],
#         [ 2.6838, -1.2614, -2.2548],
#         [-0.2446,  0.2913, -0.5397],
#         [-0.7035, -1.2288,  1.3076],
#         [-0.2855,  0.1214, -0.3448]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 2, 0, 0, 0, 2, 0])
# Epoch 3/10, Loss: 0.4271
# Epoch 4, Batch 1
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 2.0293e+00, -1.3633e+00, -1.4286e+00],
#         [-4.4362e-01, -1.0310e+00,  8.7691e-01],
#         [-1.0300e+00, -1.0035e+00,  1.1694e+00],
#         [-3.4856e+00,  4.9132e+00, -1.9944e+00],
#         [ 2.4578e+00, -1.7373e+00, -1.4712e+00],
#         [ 1.7271e-03, -1.5309e+00,  8.6708e-01],
#         [ 1.0161e+00, -1.9554e+00, -1.2498e-01],
#         [-3.5405e-01,  2.6420e-01, -5.2077e-01],
#         [ 2.0441e+00, -1.9059e+00, -1.1991e+00],
#         [ 2.8110e+00, -2.2707e+00, -1.8308e+00]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 1, 2, 1, 0, 2, 0, 1, 0, 0])
# Epoch 4, Batch 2
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-5.9380e-01, -1.3473e-03,  1.1330e-01],
#         [ 4.0240e+00, -2.8957e+00, -2.4355e+00],
#         [ 1.9410e+00, -8.7051e-01, -1.8763e+00],
#         [ 3.9470e+00, -3.5016e+00, -1.4787e+00],
#         [-8.2120e-01, -1.9396e+00,  1.9754e+00],
#         [-2.1829e+00,  3.8489e+00, -2.5823e+00],
#         [ 2.6533e-01, -1.2348e+00,  4.3917e-01],
#         [-1.2076e+00,  7.3806e-02,  2.0897e-01],
#         [ 2.3432e-01, -3.5912e-01, -4.0253e-01],
#         [-5.9427e-01, -4.7863e-01,  4.7140e-01]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 0, 2, 1, 0, 1, 1, 1])
# Epoch 4, Batch 3
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.6957,  1.3491, -1.3358],
#         [-0.4365, -2.0161,  1.6064],
#         [-0.5722, -0.9916,  0.7859],
#         [ 2.8622, -1.9115, -1.8444],
#         [-0.4858, -0.8909,  0.6852],
#         [ 2.0948, -1.9168, -1.1734],
#         [-2.9222,  4.5548, -2.2515],
#         [ 2.5028, -1.4282, -1.9006],
#         [ 0.3537, -2.5177,  1.1505],
#         [ 1.8230, -1.4881, -0.9172]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 2, 0, 2, 0, 1, 0, 2, 0])
# Epoch 4, Batch 4
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.5991e+00,  2.3390e+00, -1.1457e+00],
#         [ 1.0367e-01, -6.2288e-01,  8.0391e-04],
#         [ 2.5834e+00, -2.0680e+00, -1.6070e+00],
#         [ 3.0252e-01, -1.4699e+00,  3.7140e-01],
#         [ 1.4723e-01, -7.9644e-01, -7.8321e-02],
#         [ 1.6620e+00, -7.7512e-01, -1.6976e+00],
#         [ 1.1323e+00, -1.0340e+00, -9.6079e-01],
#         [-1.0750e+00, -1.4615e+00,  1.8208e+00],
#         [ 1.5032e+00, -4.1073e-01, -2.2295e+00],
#         [-2.7617e-01, -6.7628e-01,  5.5756e-01]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 0, 0, 0, 0, 2, 0, 2])
# Epoch 4, Batch 5
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.4289, -0.9113,  0.1060],
#         [-0.6099,  0.3505, -0.3033],
#         [ 4.3263, -1.8342, -3.5992],
#         [-3.1137,  3.8364, -1.4134],
#         [ 0.5879, -0.9228, -0.1898],
#         [-0.8779, -2.3250,  2.2505],
#         [-0.6097,  1.6220, -1.5495],
#         [ 0.6396, -1.7163,  0.4154],
#         [ 4.1573, -3.2174, -2.3562],
#         [-0.6697, -2.1848,  1.9120]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 1, 0, 1, 0, 2, 1, 2, 0, 2])
# Epoch 4, Batch 6
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.9223, -0.6951,  1.0293],
#         [-0.3973, -1.2361,  1.0455],
#         [ 0.5523, -0.5539, -0.6397],
#         [-0.4841, -1.7197,  1.4453],
#         [ 5.1896, -2.7402, -3.5695],
#         [ 0.7935, -0.7025, -1.0030],
#         [ 2.6197,  0.6445, -4.4028],
#         [-0.4117, -1.7154,  1.3856],
#         [-1.9672,  3.3290, -1.7089],
#         [-0.8277, -1.8075,  1.7791]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 0, 2, 0, 0, 0, 2, 1, 2])
# Epoch 4, Batch 7
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.0767,  0.3574,  0.2229],
#         [-0.8491, -1.6438,  1.7418],
#         [ 1.9320, -1.9919, -1.0096],
#         [-2.1673,  2.2569, -0.6292],
#         [-0.0254, -2.4012,  1.6900],
#         [-1.9711,  2.2743, -0.9116],
#         [ 0.3529, -1.6707,  0.6891],
#         [-0.2048, -0.3187, -0.1380],
#         [ 3.4379, -1.4130, -3.0736],
#         [ 4.9186, -2.5946, -3.6190]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 0, 1, 2, 1, 2, 0, 0, 0])
# Epoch 4, Batch 8
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.2855, -1.8112,  1.3742],
#         [-0.4035, -1.5780,  1.2722],
#         [ 2.4284, -1.7178, -1.3840],
#         [-3.2068,  5.0719, -2.4414],
#         [-0.3687, -1.5798,  1.2680],
#         [-0.6850,  0.2697, -0.0542],
#         [-0.6119, -1.8726,  1.6275],
#         [ 3.8748, -1.5697, -3.4145],
#         [-0.5551, -0.6813,  0.4951],
#         [ 4.3754, -2.0147, -3.6776]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 0, 1, 2, 1, 2, 0, 2, 0])
# Epoch 4, Batch 9
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.1204, -1.8650,  2.1385],
#         [-1.1257, -1.4612,  1.8336],
#         [-0.7001, -2.1646,  2.0631],
#         [-0.1940, -0.7801,  0.5471],
#         [ 1.6854, -2.1627, -0.6576],
#         [ 3.0105, -1.4805, -2.4646],
#         [-0.0945,  2.1147, -2.7332],
#         [ 3.1322, -1.4004, -2.6106],
#         [ 2.1703, -1.2705, -2.0547],
#         [-2.4487,  2.5982, -0.5618]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 2, 2, 0, 0, 1, 0, 0, 1])
# Epoch 4, Batch 10
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.4239, -1.7680,  1.4842],
#         [ 3.9448, -2.2630, -2.8941],
#         [-0.6709,  2.4056, -2.2597],
#         [-0.3876, -0.9900,  0.7192],
#         [-0.6775, -1.9996,  1.8895],
#         [ 3.5298, -1.5748, -3.0598],
#         [-2.1653,  1.8250, -0.2071],
#         [ 3.0614, -2.5878, -1.6120],
#         [-0.5223, -1.9680,  1.7450],
#         [-1.5882,  1.1986, -0.2143]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 1, 1, 2, 0, 1, 0, 2, 1])
# Epoch 4, Batch 11
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.6258, -1.9813,  1.6946],
#         [ 1.8862, -0.8730, -1.7618],
#         [-0.8686,  2.7884, -2.4308],
#         [-1.1517, -0.3459,  0.8851],
#         [-0.8788, -2.3533,  2.1616],
#         [ 3.4966, -2.4037, -2.6389],
#         [ 2.3074, -2.2094, -1.0115],
#         [-2.0369,  1.0548,  0.4242],
#         [ 3.0089, -1.3515, -2.6606],
#         [-0.8792, -0.1302,  0.5143]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 0, 1, 2, 0, 0, 1, 0, 1])
# Epoch 4, Batch 12
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 2.3653, -1.5217, -1.6513],
#         [ 2.4677, -0.8946, -2.3979],
#         [ 2.4102, -1.5486, -1.6162],
#         [-2.4484,  2.9078, -0.8197],
#         [-0.5325, -0.3591,  0.2131],
#         [-0.4591, -1.8453,  1.4511],
#         [-0.9396, -2.2755,  2.2486],
#         [-0.8899, -0.1277,  0.2590],
#         [ 2.7846, -1.5269, -2.4243],
#         [-0.4039, -0.5549,  0.1042]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 0, 0, 1, 2, 2, 2, 1, 0, 2])
# Epoch 4, Batch 13
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 1.8863, -1.6418, -1.2383],
#         [-1.4469, -1.4070,  1.9839],
#         [ 1.6293, -2.0657, -0.5174],
#         [-3.2144,  5.1412, -2.8195],
#         [ 2.9130, -1.6647, -2.4387],
#         [ 0.0234, -1.2459,  0.6145],
#         [-0.1074, -0.0186, -0.3269],
#         [-0.7658, -2.3567,  2.2422],
#         [ 4.7515, -0.8287, -5.0006],
#         [-0.7696, -2.3638,  2.1370]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 2, 0, 1, 0, 0, 1, 2, 1, 2])
# Epoch 4, Batch 14
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.1141, -2.5625,  1.5689],
#         [ 0.0682, -1.5845,  0.8385],
#         [-3.3682,  6.2672, -3.4322],
#         [-1.1202, -1.0592,  1.4979],
#         [ 0.2889,  0.3154, -1.1616],
#         [-0.6471, -2.0316,  1.7772],
#         [-1.1453, -1.3932,  1.6502],
#         [ 2.0496, -1.1940, -1.5618],
#         [ 8.9313, -3.3616, -7.4119],
#         [-0.7586, -1.6315,  1.5421]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 1, 2, 1, 2, 2, 0, 0, 2])
# Epoch 4, Batch 15
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-2.5188e+00,  2.6554e+00, -6.2073e-01],
#         [ 8.4606e-01, -1.9013e-01, -1.3537e+00],
#         [ 1.4883e+00, -1.9533e+00, -6.4467e-01],
#         [-7.2150e-01, -1.3343e+00,  1.4353e+00],
#         [ 1.0751e-01, -1.7170e+00,  9.7421e-01],
#         [-1.0376e+00, -1.5170e+00,  1.7408e+00],
# ...
#         [ 3.7723, -3.0215, -1.9393],
#         [ 2.7691, -3.1837, -0.8272],
#         [-1.7489, -2.9086,  3.4585],
#         [-0.4812, -2.4208,  2.0004],
#         [-2.2359, -2.6896,  3.5696],
#         [-1.6285,  6.5962, -5.6983],
#         [ 6.2393, -1.1786, -6.1434],
#         [ 5.4653, -2.6505, -3.9208],
#         [-3.3092, -4.0361,  5.4342]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 2, 2, 2, 1, 0, 0, 2])
# Epoch 9, Batch 16
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 5.4379, -2.0924, -4.5115],
#         [-1.3701, -2.6580,  2.7055],
#         [-0.7691, -1.6987,  1.4209],
#         [-1.2079, -0.6097,  1.0920],
#         [ 6.5357, -0.4839, -7.3901],
#         [-3.5011, -2.4706,  4.3831],
#         [-0.9034, -2.8920,  2.6016],
#         [-1.0855, -1.7338,  1.6545],
#         [-3.3354,  8.0571, -5.1421],
#         [ 5.3220, -2.0397, -4.4223]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 2, 2, 2, 0, 2, 2, 2, 1, 0])
# Epoch 9, Batch 17
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-2.6925,  7.5909, -5.3276],
#         [-1.9995, -3.3042,  3.9100],
#         [-0.6573, -1.8725,  1.6902],
#         [ 4.2961, -2.0458, -3.3214],
#         [ 6.8768, -2.1824, -5.9067],
#         [-2.3501, -3.1867,  4.0179],
#         [ 3.3479, -2.3857, -2.0261],
#         [-2.2508,  4.1903, -2.4571],
#         [-2.3501, -3.1867,  4.0179],
#         [ 2.7871, -2.6611, -1.5605]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 2, 0, 0, 2, 0, 1, 2, 0])
# Epoch 9, Batch 18
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.6309, -1.7832,  2.3307],
#         [ 5.0600, -1.6146, -4.3940],
#         [-3.1171, -0.9741,  2.8493],
#         [ 5.3388, -1.8042, -4.7324],
#         [ 2.8622, -2.5957, -1.5034],
#         [-1.8963, -1.7593,  2.3848],
#         [ 1.6602, -1.4755, -1.4099],
#         [ 4.0409, -2.0216, -3.2444],
#         [-3.6194,  7.2737, -4.1245],
#         [-3.5089, -2.8525,  4.6069]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 2, 0, 0, 2, 0, 0, 1, 2])
# Epoch 9, Batch 19
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 0.8471, -0.6342, -0.7982],
#         [-3.0758,  7.8926, -5.3796],
#         [-2.4898, -2.5492,  3.6988],
#         [ 1.6522, -0.9771, -1.8503],
#         [ 1.4944, -1.3968, -0.7576],
#         [ 2.1234, -0.2843, -2.7667],
#         [-5.8001, -3.3218,  6.8882],
#         [ 4.0021, -1.9091, -2.9967],
#         [ 2.2312, -3.5590,  0.1137],
#         [ 4.7557, -2.1665, -3.5527]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 1, 2, 0, 0, 0, 2, 0, 0, 0])
# Epoch 9, Batch 20
# outputs['Category'] shape: torch.Size([8, 3]), labels['Category'] shape: torch.Size([8])
# outputs['Category'] values: tensor([[-3.4271, -1.7264,  3.7171],
#         [ 1.8910,  0.0299, -3.3816],
#         [-2.9984, -1.6087,  3.3810],
#         [ 3.6020, -1.3701, -3.0436],
#         [ 4.3966, -0.4460, -4.9064],
#         [ 2.3649, -0.5713, -2.5112],
#         [-3.8961, -0.9833,  3.5920],
#         [ 2.5374, -0.7982, -2.6476]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 2, 0, 0, 0, 2, 0])
# Epoch 9/10, Loss: 0.2695
# Epoch 10, Batch 1
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 4.1958, -1.8502, -3.2883],
#         [-1.8500,  1.6908, -0.7633],
#         [-3.0384, -3.1097,  4.6118],
#         [-2.4637,  3.7266, -1.9034],
#         [ 3.1885, -2.1730, -1.8945],
#         [-3.7554, -4.7932,  6.3789],
#         [ 4.8262, -1.6218, -4.3629],
#         [-2.1199,  5.1436, -3.6471],
#         [ 3.3892, -2.3230, -1.9869],
#         [ 2.7758, -3.6422, -0.4135]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 1, 2, 1, 0, 2, 0, 1, 0, 0])
# Epoch 10, Batch 2
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.1791,  1.5888, -0.9812],
#         [ 6.1226, -5.1806, -2.7173],
#         [ 2.4165, -2.4308, -0.7038],
#         [ 2.8977, -3.2473, -0.6767],
#         [-4.4685, -4.5651,  6.9275],
#         [ 0.9027,  2.5308, -4.4552],
#         [ 2.9122, -2.6333, -1.3594],
#         [-0.0759,  1.2079, -1.8947],
#         [-1.6266,  2.0415, -0.7675],
#         [-2.0420,  3.0045, -1.4222]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 0, 2, 1, 0, 1, 1, 1])
# Epoch 10, Batch 3
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-2.7955,  7.5283, -5.3511],
#         [-2.6670, -3.7961,  4.7690],
#         [-1.2322, -2.5677,  2.6942],
#         [ 4.0959, -1.7628, -3.3917],
#         [-0.6430, -2.1716,  1.8543],
#         [ 3.9715, -2.0773, -2.9830],
#         [-2.1909,  4.3279, -2.7890],
#         [ 4.8881, -2.1125, -3.7899],
#         [-2.6373, -4.0235,  4.8453],
#         [ 3.7351, -2.1760, -2.3873]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 2, 0, 2, 0, 1, 0, 2, 0])
# Epoch 10, Batch 4
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-4.6086,  6.8781, -2.6375],
#         [ 2.0092, -0.3369, -2.6956],
#         [ 1.6249, -1.8643, -0.7160],
#         [ 1.8913, -1.9193, -1.0633],
#         [ 1.2391, -1.8779, -0.3621],
#         [ 4.3118, -1.3841, -3.8605],
#         [ 1.9655, -1.5812, -1.4809],
#         [-3.9413, -2.6669,  5.0031],
#         [ 4.2952, -1.4816, -3.9627],
#         [-3.1304, -2.7430,  4.3793]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 0, 0, 0, 0, 2, 0, 2])
# Epoch 10, Batch 5
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.5299, -2.3647,  2.8762],
#         [-1.7872,  2.3753, -1.1524],
#         [ 6.3457, -2.5884, -4.8467],
#         [-0.9924,  4.3768, -4.1208],
#         [ 6.0976, -1.7103, -5.6467],
#         [-1.5800, -3.2090,  3.4660],
#         [-2.8003,  5.9667, -3.6117],
#         [-0.5127, -3.3549,  2.5524],
#         [ 4.8811, -4.5139, -1.8968],
#         [-3.2191, -3.8825,  5.2194]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 1, 0, 1, 0, 2, 1, 2, 0, 2])
# Epoch 10, Batch 6
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-2.9758, -1.5932,  3.3869],
#         [-2.7887, -2.7371,  4.0143],
#         [ 4.1778, -2.2097, -3.2376],
#         [-2.0588, -2.3050,  3.1125],
#         [ 6.0211, -1.3487, -5.7489],
#         [ 3.3767, -1.7195, -2.9475],
#         [ 6.7819, -1.4585, -6.4301],
#         [-1.0974, -2.7187,  2.6699],
#         [-4.6159,  7.9312, -3.7801],
#         [-1.3490, -1.5305,  1.7558]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 0, 2, 0, 0, 0, 2, 1, 2])
# Epoch 10, Batch 7
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.2606,  3.7726, -3.1265],
#         [-2.6865, -3.4381,  4.6039],
#         [ 4.8150, -3.0245, -3.0997],
#         [-1.7299,  3.2664, -2.0629],
#         [-2.8811, -4.5112,  5.6596],
#         [-1.9089,  3.9086, -2.6421],
#         [-1.6948, -3.7409,  3.7653],
#         [ 1.7313, -0.0404, -2.5639],
#         [ 5.9247, -2.5330, -4.5782],
#         [ 4.7672, -2.1293, -3.6935]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 0, 1, 2, 1, 2, 0, 0, 0])
# Epoch 10, Batch 8
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-1.5290, -2.6555,  2.9745],
#         [-1.1696, -3.0564,  3.0381],
#         [ 5.2615, -2.8115, -3.6050],
#         [-2.3696,  5.8793, -4.1501],
#         [-0.6829, -2.8091,  2.4172],
#         [-2.0240,  4.5469, -3.0033],
#         [-3.0206, -3.5792,  4.8407],
#         [ 6.8905, -2.8526, -5.3063],
#         [-0.7948, -2.7518,  2.3291],
#         [ 3.7884,  1.0949, -6.1232]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 0, 1, 2, 1, 2, 0, 2, 0])
# Epoch 10, Batch 9
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-2.2212, -3.2463,  4.0346],
#         [-2.6010, -3.4225,  4.4758],
#         [-1.3193, -3.2498,  3.3413],
#         [-1.8817, -2.5296,  3.1772],
#         [ 4.6409, -3.6266, -2.4619],
#         [ 5.3490, -2.0060, -4.3531],
#         [-2.4649,  9.4214, -7.7645],
#         [ 4.7540, -1.8470, -3.7658],
#         [ 3.5987, -2.9907, -1.8718],
#         [-2.3895,  4.0260, -2.0629]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 2, 2, 0, 0, 1, 0, 0, 1])
# Epoch 10, Batch 10
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-2.3534, -3.8371,  4.5740],
#         [ 4.0077, -2.7219, -2.3895],
#         [-2.6674,  6.1033, -3.9594],
#         [-0.7821,  2.0754, -1.8038],
#         [-2.8435, -3.9259,  5.0371],
#         [ 7.2274, -2.7531, -5.7357],
#         [-1.1613,  2.3637, -1.7711],
#         [ 4.4053, -3.9156, -1.9654],
#         [-0.9183, -3.4058,  3.1210],
#         [-0.3900,  2.0830, -2.2502]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 1, 1, 2, 0, 1, 0, 2, 1])
# Epoch 10, Batch 11
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-4.5861, -2.8695,  5.6567],
#         [ 4.0935, -2.6978, -2.3649],
#         [ 0.0299,  3.8139, -4.5203],
#         [-1.4137,  2.0454, -1.3184],
#         [-2.4594, -4.8127,  5.2852],
#         [ 3.3137, -3.5600, -1.4802],
#         [ 4.7167, -3.2954, -2.6784],
#         [-1.2230,  2.4419, -2.0033],
#         [ 5.0212, -2.4662, -3.7069],
#         [-1.8151,  2.9247, -1.7200]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 0, 1, 2, 0, 0, 1, 0, 1])
# Epoch 10, Batch 12
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 5.5098, -2.1131, -4.5615],
#         [ 4.2922, -1.6887, -3.5990],
#         [ 4.8513, -2.0524, -3.8773],
#         [-3.4701,  7.4466, -4.4915],
#         [-2.5925, -1.8507,  3.2089],
#         [-0.7125, -3.7328,  3.0244],
#         [-4.8748, -5.3347,  7.7388],
#         [-1.1444,  5.2876, -4.8222],
#         [ 4.2474, -2.3435, -2.9279],
#         [-0.9194, -2.9608,  2.5629]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 0, 0, 1, 2, 2, 2, 1, 0, 2])
# Epoch 10, Batch 13
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 4.3469, -2.9587, -2.5467],
#         [-3.6774, -3.1785,  5.1215],
#         [ 3.9293, -3.7708, -1.4052],
#         [-0.8424,  5.5729, -5.5049],
#         [ 5.0516, -3.6205, -2.8735],
#         [ 4.0499, -2.1983, -3.2233],
#         [-2.1096,  4.6567, -3.0517],
#         [-2.4083, -4.3507,  5.1424],
#         [-1.2846,  3.2432, -2.4049],
#         [-0.7301, -2.4067,  2.0882]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 2, 0, 1, 0, 0, 1, 2, 1, 2])
# Epoch 10, Batch 14
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-0.8040, -3.5644,  3.0541],
#         [-0.4853, -3.3282,  2.6929],
#         [ 0.0434,  4.8842, -5.5446],
#         [-2.1943, -2.2823,  3.2733],
#         [-2.9834,  7.4585, -5.1822],
#         [-0.8528, -2.2680,  1.9472],
#         [-1.0995, -2.6704,  2.6762],
#         [ 7.5185, -2.3716, -6.4573],
#         [ 8.3119, -2.4454, -7.3012],
#         [-2.4510, -3.1498,  4.0362]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 2, 1, 2, 1, 2, 2, 0, 0, 2])
# Epoch 10, Batch 15
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-3.3329,  5.7985, -2.9990],
#         [ 4.7649, -3.6994, -2.4301],
#         [ 3.6818, -3.8273, -1.2649],
#         [-1.8028, -2.8207,  3.4454],
#         [-1.2800, -2.3434,  2.6319],
#         [-2.7735, -2.3744,  3.8397],
#         [-2.2471,  6.9715, -5.4732],
#         [ 7.4669, -0.6953, -8.0456],
#         [ 5.4697, -2.5024, -4.0264],
#         [-3.6084, -4.2830,  5.8765]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 0, 0, 2, 2, 2, 1, 0, 0, 2])
# Epoch 10, Batch 16
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 5.4328, -2.2998, -4.2795],
#         [-1.7549, -2.8964,  3.2786],
#         [-0.8412, -2.3256,  2.0137],
#         [-0.7067, -2.0665,  1.8490],
#         [ 7.7759,  0.6252, -9.9966],
#         [-3.2648, -1.9951,  3.8693],
#         [-1.1155, -2.8615,  2.7971],
#         [-1.6995, -2.6509,  3.0464],
#         [-4.2043,  9.6416, -5.9262],
#         [ 5.4989, -2.2411, -4.4027]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 2, 2, 2, 0, 2, 2, 2, 1, 0])
# Epoch 10, Batch 17
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-3.8055,  9.6956, -6.4052],
#         [-2.5802, -3.3479,  4.4281],
#         [-1.8217, -1.6027,  2.4048],
#         [ 5.3875, -2.2934, -4.3411],
#         [ 6.7560, -2.3213, -5.6263],
#         [-2.5027, -3.2010,  4.1393],
#         [ 3.4599, -1.7029, -2.8807],
#         [-1.0172,  1.7501, -1.2376],
#         [-2.5027, -3.2010,  4.1393],
#         [ 4.4315, -3.6579, -2.4668]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([1, 2, 2, 0, 0, 2, 0, 1, 2, 0])
# Epoch 10, Batch 18
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[-3.1536, -0.4586,  2.4390],
#         [ 4.9330, -1.7560, -4.1427],
#         [-4.4434,  0.3869,  2.7428],
#         [ 6.1463, -1.5554, -5.9216],
#         [ 3.7307, -2.5903, -2.5233],
#         [-2.5886, -2.0790,  3.2103],
#         [ 3.9706, -2.9644, -2.5068],
#         [ 4.1220, -2.0906, -3.1653],
#         [-1.6600,  4.2160, -3.0494],
#         [-4.9464, -1.4696,  4.6109]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 2, 0, 0, 2, 0, 0, 1, 2])
# Epoch 10, Batch 19
# outputs['Category'] shape: torch.Size([10, 3]), labels['Category'] shape: torch.Size([10])
# outputs['Category'] values: tensor([[ 3.3858, -1.7117, -2.4471],
#         [-3.2714,  9.1407, -6.5327],
#         [-3.9539, -2.4584,  4.8376],
#         [ 2.2083, -1.3458, -2.0877],
#         [ 3.5393, -2.1448, -2.1925],
#         [ 1.3856, -1.1579, -1.1604],
#         [-6.0811, -2.7713,  6.6306],
#         [ 3.5468, -1.8339, -2.5552],
#         [ 2.6084, -3.5405, -0.3426],
#         [ 3.9335, -2.0403, -2.7484]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([0, 1, 2, 0, 0, 0, 2, 0, 0, 0])
# Epoch 10, Batch 20
# outputs['Category'] shape: torch.Size([8, 3]), labels['Category'] shape: torch.Size([8])
# outputs['Category'] values: tensor([[-3.7020, -1.8199,  3.9614],
#         [ 4.0929, -2.2678, -3.5364],
#         [-4.4988, -0.3536,  3.5410],
#         [ 4.0290, -1.4372, -3.4978],
#         [ 4.1050, -0.2039, -4.8710],
#         [ 2.9469, -0.3941, -3.3669],
#         [-3.8502, -1.6008,  3.9953],
#         [ 1.9809, -0.0124, -2.8598]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# labels['Category'] values: tensor([2, 0, 2, 0, 0, 0, 2, 0])
# Epoch 10/10, Loss: 0.2675

# %%
def validate_model(model, val_dataloader, device):
    model.eval()  # Set model to evaluation mode
    total_loss = 0
    num_samples = 0
    
    criterion_category = nn.CrossEntropyLoss()
    criterion_regression = nn.MSELoss()
    criterion_binary = nn.BCELoss()

    with torch.no_grad():  # No gradient calculation
        for images, labels in val_dataloader:
            images = images.to(device)
            
            # Forward pass
            outputs = model(images)
            
            loss_category = criterion_category(outputs['Category'], labels['Category'].long().to(images.device))
            loss_shape_size = criterion_regression(outputs['Shape_and_Size'], labels['Shape_and_Size'].float().to(images.device))
            loss_texture = criterion_regression(outputs['Texture'], labels['Texture'].float().to(images.device))
            loss_color = criterion_regression(outputs['Color'], labels['Color'].float().to(images.device))
            loss_firmness = criterion_regression(outputs['Firmness'], labels['Firmness'].float().to(images.device))
            loss_batch_consistency = criterion_regression(outputs['Batch_Consistency'], labels['Batch_Consistency'].float().to(images.device))
            loss_damaged = criterion_binary(outputs['Damaged'], labels['Damaged'].float().unsqueeze(1).to(images.device))
            loss_quality = criterion_regression(
                outputs['Overall_Quality'], 
                labels['Overall_Quality'].float().view(-1, 1).to(images.device)
        )            
            # Total loss
            total_batch_loss = (
                loss_category + loss_shape_size + loss_texture + 
                loss_color + loss_firmness + loss_batch_consistency + 
                loss_damaged + loss_quality
            )
            print(f"Validation Loss: {total_batch_loss.item():.4f}")
            total_loss += total_batch_loss.item() * images.size(0)  # Accumulate loss
            num_samples += images.size(0)
    
    avg_loss = total_loss / num_samples
    print(f"Loss: {running_loss / len(val_loader)}")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
validate_model(model, val_loader, device)
# Out:
# Validation Loss: 1.2798
# Validation Loss: 3.2403
# Validation Loss: 1.1765
# Validation Loss: 0.9682
# Validation Loss: 2.4783
# Validation Loss: 1.2210
# Validation Loss: 2.4224
# Validation Loss: 1.9946
# Validation Loss: 1.4113
# Validation Loss: 2.9532
# Validation Loss: 2.5562
# Validation Loss: 2.3952
# Validation Loss: 2.1567
# Validation Loss: 1.3153
# Validation Loss: 0.2792
# Validation Loss: 0.3763
# Validation Loss: 1.2500
# Validation Loss: 1.0449
# Validation Loss: 0.2646
# Validation Loss: 0.2716
# Loss: 0.2675023630261421

# %%
import torch
from torchvision import transforms
from PIL import Image, ImageFile

# Allow loading of truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Path to your random image
random_image_path = "0629.jpg"

# Preprocessing (same as used during training/validation)
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Ensure the image size matches the input size of the model
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Same normalization as training
])

# Load and preprocess the image
image = Image.open(random_image_path).convert("RGB")
input_image = transform(image).unsqueeze(0)  # Add batch dimension

# Move image to the appropriate device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_image = input_image.to(device)

# Ensure model is in evaluation mode
model.eval()

# Inference
with torch.no_grad():
    output = model(input_image)
category = torch.argmax(output["Category"], dim=1).item()
category_name = list(category_mapping.keys())[list(category_mapping.values()).index(category)]

# Interpret the output
output_dict = {
    "Category": category_name,  # Multi-class classification
    "Shape_and_Size": output["Shape_and_Size"].item(),
    "Texture": output["Texture"].item(),
    "Color": output["Color"].item(),
    "Firmness": output["Firmness"].item(),
    "Batch_Consistency": output["Batch_Consistency"].item(),
    "Damaged": torch.round(output["Damaged"]).item(),  # Binary classification (round to 0 or 1)
    "Overall_Quality": output["Overall_Quality"].item()
}


# Print the results
print("Predicted Parameters:")
for key, value in output_dict.items():
    print(f"{key}: {value}")
# Out:
# Predicted Parameters:
# Category: Unripe
# Shape_and_Size: 0.636222779750824
# Texture: 0.5969353318214417
# Color: 0.5918222069740295
# Firmness: 0.6659048795700073
# Batch_Consistency: 0.6495285034179688
# Damaged: 0.0
# Overall_Quality: 0.7727771401405334

# %%
torch.save(model.state_dict(), 'complete_model.pt')
